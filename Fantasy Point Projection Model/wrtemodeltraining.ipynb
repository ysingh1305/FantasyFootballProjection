# %% [markdown]
# #### Imports

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# #### Starting Connection and Querying Data from Supabase

# %%
# Load environment variables from .env
load_dotenv()

# Fetch variables
USER = os.getenv("user")
PASSWORD = os.getenv("password")
HOST = os.getenv("host")
PORT = os.getenv("port")
DBNAME = os.getenv("dbname")

# Construct the SQLAlchemy connection string
DATABASE_URL = f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}?sslmode=require"

# Create the SQLAlchemy engine
engine = create_engine(DATABASE_URL)
# If using Transaction Pooler or Session Pooler, we want to ensure we disable SQLAlchemy client side pooling -
# https://docs.sqlalchemy.org/en/20/core/pooling.html#switching-pool-implementations
# engine = create_engine(DATABASE_URL, poolclass=NullPool)

# Test the connection
try:
    with engine.connect() as connection:
        print("Connection successful!")
except Exception as e:
    print(f"Failed to connect: {e}")
# Out:
# Connection successful!

# %%
query = """
SELECT *
FROM "WRTEPointProjection"
WHERE season BETWEEN 2018 AND 2024
"""

wrte_df = pd.read_sql(query, engine)
print(wrte_df.shape)
wrte_df.head()
# Out:
# (24797, 43)
#     player_id player_name team  season  week opponent_team  \
# 0  00-0021547     A.Gates  LAC    2018     1            KC
# 1  00-0021547     A.Gates  LAC    2018     2           BUF
# 2  00-0021547     A.Gates  LAC    2018     3            LA
# 3  00-0021547     A.Gates  LAC    2018     4            SF
# 4  00-0021547     A.Gates  LAC    2018     5            LV
#
#    fantasy_points_ppr  targets_prev  receptions_prev  receiving_yards_prev  \
# 0                 5.6          52.0             30.0                 316.0
# 1                 0.0          52.0             30.0                 316.0
# 2                 7.5          52.0             30.0                 316.0
# 3                10.7          52.0             30.0                 316.0
# 4                 3.9          52.0             30.0                 316.0
#
#    ...  wrte_targets_allowed_roll3_mean  wrte_targets_allowed_roll5_mean  \
# 0  ...                        30.000000                            29.75
# 1  ...                        26.000000                            26.50
# 2  ...                        21.500000                            23.75
# 3  ...                        30.000000                            31.75
# 4  ...                        28.333333                            27.75
#
#    wrte_receptions_allowed_roll3_mean  wrte_receptions_allowed_roll5_mean  \
# 0                           16.000000                               18.00
# 1                           17.500000                               16.25
# 2                           13.500000                               13.50
# 3                           17.333333                               18.50
# 4                           16.666667                               15.75
#
#    wrte_rec_yards_allowed_roll3_mean  wrte_rec_yards_allowed_roll5_mean  \
# 0                         208.000000                             225.50
# 1                         212.000000                             175.25
# 2                         157.500000                             164.25
# 3                         240.666667                             254.50
# 4                         263.666667                             241.75
#
#    wrte_rec_tds_allowed_roll3_mean  wrte_rec_tds_allowed_roll5_mean  \
# 0                         1.000000                             0.75
# 1                         2.000000                             1.25
# 2                         0.000000                             0.25
# 3                         2.666667                             2.50
# 4                         2.000000                             1.75
#
#    wrte_fp_allowed_roll3_mean  wrte_fp_allowed_roll5_mean
# 0                       41.30                      44.600
# 1                       51.30                      41.925
# 2                       29.70                      31.150
# 3                       58.80                      60.500
# 4                       57.06                      52.645
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Building Feature and Target Set

# %%
TARGET = "fantasy_points_ppr"

keys_df = wrte_df[["player_id", "player_name", "season", "week", "team", "opponent_team"]].copy()

drop_cols = ["player_id", "player_name", "season", "week", "team", "opponent_team", TARGET]
X = wrte_df.drop(columns=[c for c in drop_cols if c in wrte_df.columns]).copy()
y = wrte_df[TARGET].copy()

X = X.drop(columns=["fantasy_points_ppr_prev"], errors="ignore")

print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (24797, 35) y shape: (24797,)

# %%
train_mask = wrte_df["season"].between(2018, 2022)
val_mask   = wrte_df["season"].eq(2023)
test_mask  = wrte_df["season"].eq(2024)

X_train, y_train = X.loc[train_mask], y.loc[train_mask]
X_val,   y_val   = X.loc[val_mask],   y.loc[val_mask]
X_test,  y_test  = X.loc[test_mask],  y.loc[test_mask]

keys_train = keys_df.loc[train_mask].reset_index(drop=True)
keys_val   = keys_df.loc[val_mask].reset_index(drop=True)
keys_test  = keys_df.loc[test_mask].reset_index(drop=True)

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (17476, 35) (3661, 35) (3660, 35)

# %% [markdown]
# ### Linear Regression Model

# %%
X_train, X_val, X_test = X_train.fillna(0), X_val.fillna(0), X_test.fillna(0)
y_train, y_val, y_test = y_train.fillna(0), y_val.fillna(0), y_test.fillna(0)

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm_val_pred = linear_model.predict(X_val)
lm_test_pred = linear_model.predict(X_test)

# %%
mse = mean_squared_error(y_val, lm_val_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_val, lm_val_pred)

print(f"Linear Regression VAL RMSE: {rmse:.4f}")
print(f"Linear Regression VAL MAE : {mae:.4f}")
# Out:
# Linear Regression VAL RMSE: 5.8784
# Linear Regression VAL MAE : 4.3482

# %%
mse = mean_squared_error(y_test, lm_test_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, lm_test_pred)

print(f"Linear Regression TEST RMSE: {rmse:.4f}")
print(f"Linear Regression TEST MAE : {mae:.4f}")
# Out:
# Linear Regression TEST RMSE: 5.9471
# Linear Regression TEST MAE : 4.3779

# %% [markdown]
# #### LightGBM

# %%
model = lgb.LGBMRegressor(
    n_estimators=5000,
    learning_rate=0.03,
    num_leaves=63,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.0,
    reg_lambda=0.0,
    random_state=42,
    n_jobs=-1
)

model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    eval_metric="l2",  
    callbacks=[lgb.early_stopping(stopping_rounds=200, verbose=True)]
)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004588 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3273
# [LightGBM] [Info] Number of data points in the train set: 17476, number of used features: 35
# [LightGBM] [Info] Start training from score 7.057889
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [121]	valid_0's l2: 34.1857
# LGBMRegressor(colsample_bytree=0.8, learning_rate=0.03, n_estimators=5000,
#               n_jobs=-1, num_leaves=63, random_state=42, subsample=0.8)

# %%
val_pred = model.predict(X_val, num_iteration=model.best_iteration_)
mse = mean_squared_error(y_val, val_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_val, val_pred)

print(f"VAL RMSE: {rmse:.4f}")
print(f"VAL MAE : {mae:.4f}")
print("Best iteration:", model.best_iteration_)
lgb.plot_importance(model, max_num_features=20, importance_type='gain', figsize=(8,6))
# Out:
# VAL RMSE: 5.8469
# VAL MAE : 4.2895
# Best iteration: 121
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
test_pred = model.predict(X_test, num_iteration=model.best_iteration_)
mse = mean_squared_error(y_test, test_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, test_pred)

print(f"TEST RMSE: {rmse:.4f}")
print(f"TEST MAE : {mae:.4f}")
print("Best iteration:", model.best_iteration_)
lgb.plot_importance(model, max_num_features=20, importance_type='gain', figsize=(8,6))
# Out:
# TEST RMSE: 5.9021
# TEST MAE : 4.3334
# Best iteration: 121
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
val_preds_df = keys_val.copy()
val_preds_df["pred_fantasy_points_ppr"] = val_pred
val_preds_df["actual_fantasy_points_ppr"] = y_val.reset_index(drop=True)

val_preds_df.sort_values(["season", "week", "pred_fantasy_points_ppr"], ascending=[True, True, False]).head(20)
# Out:
#        player_id  player_name  season  week team opponent_team  \
# 1627  00-0035676      A.Brown    2023     1  PHI            NE
# 179   00-0031381      D.Adams    2023     1   LV           DEN
# 1911  00-0036322  J.Jefferson    2023     1  MIN            TB
# 289   00-0031588      S.Diggs    2023     1  BUF           NYJ
# 2353  00-0036912      D.Smith    2023     1  PHI            NE
# 196   00-0031408      M.Evans    2023     1   TB           MIN
# 1969  00-0036358       C.Lamb    2023     1  DAL           NYG
# 519   00-0033040       T.Hill    2023     1  MIA           LAC
# 2548  00-0037239      C.Olave    2023     1   NO           TEN
# 1597  00-0035659   T.McLaurin    2023     1  WAS           ARI
# 1176  00-0034775       C.Kirk    2023     1  JAX           IND
# 847   00-0033921     C.Godwin    2023     1   TB           MIN
# 2337  00-0036900      J.Chase    2023     1  CIN           CLE
# 235   00-0031544     A.Cooper    2023     1  CLE           CIN
# 2152  00-0036613     J.Waddle    2023     1  MIA           LAC
# 1215  00-0034827      D.Moore    2023     1  CHI            GB
# 2019  00-0036410    T.Higgins    2023     1  CIN           CLE
# 2299  00-0036963  A.St. Brown    2023     1  DET            KC
# 1822  00-0036252    M.Pittman    2023     1  IND           JAX
# 1290  00-0034960     J.Meyers    2023     1   LV           DEN
#
#       pred_fantasy_points_ppr  actual_fantasy_points_ppr
# 1627                22.655145                       14.9
# 179                 22.153076                       12.6
# 1911                19.548713                       24.0
# 289                 18.855891                       26.2
# 2353                17.638312                       17.7
# 196                 16.726329                       18.6
# 1969                16.250266                       11.7
# 519                 15.394479                       44.5
# 2548                15.175845                       19.2
# 1597                14.636100                        5.1
# 1176                14.591753                        1.9
# 847                 14.531938                       10.1
# 2337                14.492915                        9.1
# 235                 14.079499                        6.7
# 2152                14.008330                       11.8
# 1215                13.523624                        4.5
# 2019                13.412020                        0.0
# 2299                13.096740                       19.1
# 1822                13.073348                       23.7
# 1290                12.938322                       29.1

# %%
test_preds_df = keys_test.copy()
test_preds_df["pred_fantasy_points_ppr"] = test_pred
test_preds_df["actual_fantasy_points_ppr"] = y_test.reset_index(drop=True)

test_preds_df.sort_values(["season", "week", "pred_fantasy_points_ppr"], ascending=[True, True, False]).head(20)
# Out:
#        player_id  player_name  season  week team opponent_team  \
# 1232  00-0035676      A.Brown    2024     1  PHI            GB
# 341   00-0033040       T.Hill    2024     1  MIA           JAX
# 1906  00-0036963  A.St. Brown    2024     1  DET            LA
# 1489  00-0036358       C.Lamb    2024     1  DAL           CLE
# 3104  00-0039075      P.Nacua    2024     1   LA           DET
# 128   00-0031408      M.Evans    2024     1   TB           WAS
# 33    00-0030279      K.Allen    2024     1  CHI           TEN
# 156   00-0031544     A.Cooper    2024     1  CLE           DAL
# 1445  00-0036322  J.Jefferson    2024     1  MIN           NYG
# 62    00-0030506      T.Kelce    2024     1   KC           BAL
# 904   00-0034827      D.Moore    2024     1  CHI           TEN
# 1868  00-0036900      J.Chase    2024     1  CIN            NE
# 1396  00-0036261      B.Aiyuk    2024     1   SF           NYJ
# 1184  00-0035640    D.Metcalf    2024     1  SEA           DEN
# 590   00-0033885      D.Njoku    2024     1  CLE           DAL
# 1639  00-0036554    N.Collins    2024     1  HOU           IND
# 1885  00-0036912      D.Smith    2024     1  PHI            GB
# 114   00-0031381      D.Adams    2024     1   LV           LAC
# 78    00-0030564    D.Hopkins    2024     1  TEN           CHI
# 189   00-0031588      S.Diggs    2024     1  HOU           IND
#
#       pred_fantasy_points_ppr  actual_fantasy_points_ppr
# 1232                21.068872                       22.9
# 341                 20.355719                       26.0
# 1906                20.346428                        4.3
# 1489                18.911206                       13.6
# 3104                18.537003                        8.2
# 128                 17.684799                       23.1
# 33                  17.545636                        6.9
# 156                 17.124250                        3.6
# 1445                16.714469                       15.9
# 62                  16.677166                        6.4
# 904                 16.650232                       10.0
# 1868                15.893110                       12.2
# 1396                15.412372                        4.8
# 1184                15.370492                        5.9
# 590                 14.964933                        8.4
# 1639                14.863880                       17.7
# 1885                14.691583                       15.4
# 114                 14.587858                       10.9
# 78                  14.484067                        1.8
# 189                 14.304757                       21.9

# %% [markdown]
# ###### Similar to the previous models for QBs and RBs, the Linear Regression and LightGBM models achieved similar performance across RMSE and MAE. However, what is surprising is how well the model performed for WRs/TEs. The dataset is by far the largest as there are more WRs and TEs in the NFL. Yet, the model achieved a RMSE of 5.9 on the test set which is significantly lower than ESPN's model (6.78 RMSE).
